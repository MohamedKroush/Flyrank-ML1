# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MohamedKroush/Flyrank-ML1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Answer: Ranking / Scoring. Per the framing skill's task-type table, "which pages first?" maps to Ranking/Scoring — the goal is to score every content page and rank them by review priority, not to sort into fixed categories (classification) or find unlabeled groups (clustering).

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Answer: The starter proxy target is is_declining_label (from trend_direction == "down"), computed from the current window — a defined-rule proxy, not yet an observed future outcome. A stronger target: did this page's traffic decline over the next 30 days, built from a prior-window → future-window split on the warehouse daily fact table. Per the data skill's leakage rule, trend_direction/trend_pct can never be features, since the label is derived from them.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Answer: Precision@50 — of the top 50 pages flagged for review, what fraction are genuinely declining? This matches the real decision: a content team has limited review capacity, so the top of the ranked list must be trustworthy, not the overall accuracy across every page.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Answer: One row = one pseudonymized content page, with trailing-90-day metrics.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules

REPO_URL = "https://github.com/MohamedKroush/Flyrank-ML1"

REPO_DIR = "Flyrank-ML1"

if IN_COLAB:

    if not os.path.isdir(REPO_DIR):

        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

    os.chdir(REPO_DIR)

print("Working dir:", os.getcwd())

assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found"

print("Ready.")

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

unit_df = df[["content_id", "client_id", "impressions_90d", "days_since_last_update",

              "avg_position", "trend_direction"]].head(5)

print(f"Total rows: {len(df)}, unique content_id: {df['content_id'].nunique()}")

unit_df
# Out:
# Working dir: /content/Flyrank-ML1/Flyrank-ML1/Flyrank-ML1/Flyrank-ML1/Flyrank-ML1
# Ready.
# Total rows: 30000, unique content_id: 30000
#              content_id          client_id  impressions_90d  \
# 0  content_304f48230142  client_f369cb89fc             3803
# 1  content_a1fb4e703a9e  client_4e07408562            15320
# 2  content_9aa793d4d895  client_7f2253d7e2            12581
# 3  content_331d6c4de07b  client_19581e27de            11751
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140
#
#    days_since_last_update  avg_position trend_direction
# 0                      20          10.6            down
# 1                      25          20.3            down
# 2                      20          36.5            down
# 3                      22           6.2          stable
# 4                      14          44.0            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Answer: A fixed rule (e.g. "stale AND visible") only checks a couple of thresholds. Decline risk actually depends on many interacting signals — staleness, visibility, position, engagement, content type — combining in ways an if/else can't capture. The starter pipeline proved this: the hand rule hit Precision@50 = 0.240, while the learned random forest hit 0.740 — roughly 3x better. That gap is the evidence this is a real ML problem.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
